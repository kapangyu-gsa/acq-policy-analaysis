# %%
import utilities

# %%
df = utilities.load_contract_opportunities_archived_data([1950, 1970, '1980', 'Test', 1990])
df.head()
# Out:
# WARNING: File FY1950_archived_opportunities.csv is not found.
# WARNING: File FYTest_archived_opportunities.csv is not found.
# WARNING: File FY1990_archived_opportunities.csv is not found.
#                            NoticeId  \
# 0  20247088f9ce8dce999b95a74f74d6c0
# 1  1dec445b5f9d5503a01dba357552cd72
# 2  3ca79d2b830f13bdc4a384d63d9b2d4b
# 3  c81b3464f4e9b41d348a9045be32c274
#
#                                                Title                   Sol#  \
# 0          49--Maintenance and Repair Shop Equipment   FA8532--0-9--R-20791
# 1  66 -- HAAKE Laboratory Micro Rheology Compound...           108-00015-07
# 2  Q--MEDICAL AND ENVIRONMENTAL SUPPORT CONTRACT ...  NASA-SNOTE-070622-002
# 3                         25--CONNECTING ROD, PISTON       SP0750-02-R-1575
#
#         Department/Ind.Agency  CGAC                       Sub-Tier FPDS Code  \
# 0                         NaN   NaN                            NaN       NaN
# ...

# %%
df.dtypes

# %%
df = utilities.load_contract_opportunities_archived_data([1970])
df.head()
# Out:
#   ArchiveDate  AwardDate
# 0  2019-06-25 2009-09-29
# 1  2007-09-25        NaT
# 2  2008-06-22        NaT

# %%
df.shape

# %%
from sql_mapper import sql_mapper

mapper = sql_mapper()

mapper.add_contract_opportunity_records_to_DB([1970])
# Out:
# 2020-10-21 16:21:37,327 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-10-21 16:21:37,328 INFO sqlalchemy.engine.base.Engine ()
# 2020-10-21 16:21:37,329 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-10-21 16:21:37,330 INFO sqlalchemy.engine.base.Engine ()
# 2020-10-21 16:21:37,332 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("ContractOpportunities")
# 2020-10-21 16:21:37,333 INFO sqlalchemy.engine.base.Engine ()
# 2020-10-21 16:21:39,339 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-10-21 16:21:39,343 INFO sqlalchemy.engine.base.Engine ROLLBACK
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1126
# ...
